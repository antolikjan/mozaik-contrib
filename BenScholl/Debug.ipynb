# %%
import cProfile
import pstats
import neo.core.spiketrain
import importlib
importlib.reload(neo.core.spiketrain)
from neo.core.spiketrain import SpikeTrain
from pstats import SortKey
from quantities import ms
import pickle

with open("dump.pickle", 'wb') as f:
     pickle.dump([SpikeTrain([1,2,3,1,5,6]*ms,t_stop=10000) for i in range(1000)],f)
f.close()

print("AALLLLLLLLLA")

def aaa():
    with open("dump.pickle", 'rb') as f:
         sps = pickle.load(f)
    f.close()
       
cProfile.run('aaa()', 'restats_after_after')
p = pstats.Stats('restats_after_after')
p.sort_stats(SortKey.CUMULATIVE).print_stats(15)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
p = pstats.Stats('restats_after_after')
p.sort_stats(SortKey.CUMULATIVE).print_stats(15)
# Out:
# Sun Jan 19 20:14:20 2025    restats_after_after
#
#          76046183 function calls (75545980 primitive calls) in 105.477 seconds
#
#    Ordered by: cumulative time
#    List reduced from 239 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        98    3.754    0.038  189.140    1.930 {built-in method time.sleep}
#       2/1    0.001    0.000  107.627  107.627 {built-in method builtins.exec}
#        24    0.037    0.002  107.038    4.460 /usr/lib/python3.12/asyncio/base_events.py:1910(_run_once)
#   1500003    1.821    0.000   69.920    0.000 /home/antolikjan/virt_env/mozaikluca/lib/python3.12/site-packages/quantities/quantity.py:785(_reconstruct_quantity)
#   2000012    3.629    0.000   66.628    0.000 /home/antolikjan/virt_env/mozaikluca/lib/python3.12/site-packages/quantities/quantity.py:118(__new__)
# ...

# %%
p = pstats.Stats('restats_before')
p.sort_stats(SortKey.CUMULATIVE).print_stats(15)
p = pstats.Stats('restats_after_after')
p.sort_stats(SortKey.CUMULATIVE).print_stats(15)
# Out:
# Sat Jan 18 18:21:15 2025    restats_before
#
#          26240257 function calls (25140052 primitive calls) in 32.923 seconds
#
#    Ordered by: cumulative time
#    List reduced from 245 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.000    0.000   37.352   37.352 {built-in method builtins.exec}
#         1    0.004    0.004   37.115   37.115 /tmp/ipykernel_180198/944964142.py:17(aaa)
#         1    1.425    1.425   36.889   36.889 {built-in method _pickle.load}
#    500050    1.002    0.000   20.019    0.000 /home/antolikjan/virt_env/mozaikluca/lib/python3.12/site-packages/quantities/registry.py:62(__getitem__)
#    100000    0.324    0.000   19.224    0.000 /home/antolikjan/virt_env/mozaikluca/lib/python3.12/site-packages/neo/core/spiketrain.py:96(_new_spiketrain)
# ...

# %%
import sys
import matplotlib.animation
import numpy
import mozaik
import importlib
importlib.reload(mozaik)
from mozaik.controller import run_workflow, setup_logging
from mozaik.storage.datastore import Hdf5DataStore,PickledDataStore
from parameters import ParameterSet
from mozaik.visualization.plotting import *
from mozaik.analysis.technical import NeuronAnnotationsToPerNeuronValues
from mozaik.tools.mozaik_parametrized import colapse, colapse_to_dictionary, MozaikParametrized
from mozaik.analysis.analysis import *
from mozaik.analysis.vision import *
from mozaik.storage.queries import *
from mozaik.visualization.helper_functions import *

import neo.core.spiketrain
import importlib
importlib.reload(neo.core.spiketrain)
from neo.core.spiketrain import SpikeTrain


# %matplotlib inline
stim_sheet_name = "V1_Exc_L2/3"
ddir = '/home/antolikjan/projects/mozaikluca/mozaik-contrib/BenScholl/GRAT_STIM=0.06_EXC_LARGE_C2_4/SelfSustainedPushPull_ParameterSearch_____null_stimulus_period:150_trial:1'

setup_logging()
data_store = PickledDataStore(load=True,parameters=ParameterSet({'root_directory':ddir,'store_stimuli': None}),replace=True)

# %%
import cProfile
from neo.core.spiketrain import SpikeTrain
from quantities import ms

dsv = param_filter_query(data_store,sheet_name='V1_Exc_L2/3',st_direct_stimulation_name='Injection',st_orientation=0,st_contrast=4,st_trial=[0])
dsv.print_content()

def aaa1():
    for seg in dsv.get_segments()[:100]:
        seg.get_spiketrains()
cProfile.run('aaa1()', 'restats_opton')

import pstats
from pstats import SortKey

p = pstats.Stats('restats_opton')
p.sort_stats(SortKey.CUMULATIVE).print_stats(5)
# Out:
#   DSV info:
#      Number of recordings: 60
#        FullfieldDriftingSinusoidalGrating : 60
#      Number of ADS: 30
#        PerNeuronValue : 30
#   Loading 0
#   Loading 1
#   Loading 2
#   Loading 3
#   Loading 4
#   Loading 5
#   Loading 6
#   Loading 7
#   Loading 8
#   Loading 9
#   Loading 10
#   Loading 11
#   Loading 12
#   Loading 13
#   Loading 14
#   Loading 15
#   Loading 16
#   Loading 17
#   Loading 18
#   Loading 19
#   Loading 20
#   Loading 21
#   Loading 22
#   Loading 23
#   Loading 24
#   Loading 25
#   Loading 26
#   Loading 27
#   Loading 28
#   Loading 29
# Sat Jan 18 19:46:28 2025    restats_opton
#
#          72771609 function calls (70592591 primitive calls) in 98.429 seconds
#
#    Ordered by: cumulative time
#    List reduced from 315 to 5 due to restriction <5>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.000    0.000  117.647  117.647 {built-in method builtins.exec}
# ...

# %%
p = pstats.Stats('restats_opton')
p.sort_stats(SortKey.CUMULATIVE).print_stats(15)
# Out:
# Sat Jan 18 19:46:28 2025    restats_opton
#
#          72771609 function calls (70592591 primitive calls) in 98.429 seconds
#
#    Ordered by: cumulative time
#    List reduced from 315 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.000    0.000  117.647  117.647 {built-in method builtins.exec}
#         1    0.000    0.000  117.645  117.645 /tmp/ipykernel_185961/1478431308.py:8(aaa1)
#        30    0.000    0.000  117.635    3.921 /home/antolikjan/virt_env/mozaikluca/lib/python3.12/site-packages/mozaik/storage/neo_neurotools_wrapper.py:47(get_spiketrains)
#        30    5.726    0.191  114.491    3.816 {built-in method _pickle.load}
#        30    0.012    0.000  111.078    3.703 /home/antolikjan/virt_env/mozaikluca/lib/python3.12/site-packages/mozaik/storage/neo_neurotools_wrapper.py:254(load_full)
# ...

# %%
sps =[]

def aaa2():
    for seg in dsv.get_segments()[:10]:
        for st in seg.get_spiketrains():
            sps.append(st.magnitude)
cProfile.run('aaa2()', 'restats2')

# %%
import cProfile
import pstats
from neo.core.spiketrain import SpikeTrain
from pstats import SortKey
from quantities import ms
def aaa3():
    for i in range(0,100000):
        a = SpikeTrain([1,2]*ms,t_stop=10000)
        
cProfile.run('aaa3()', 'restats3')
p = pstats.Stats('restats3')
p.sort_stats(SortKey.CUMULATIVE).print_stats(5)
# Out:
# Sat Jan 18 14:41:51 2025    restats3
#
#          60629860 function calls (57329859 primitive calls) in 76.751 seconds
#
#    Ordered by: cumulative time
#    List reduced from 128 to 5 due to restriction <5>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.087    0.043   76.957   76.957 {built-in method builtins.exec}
#    100000    0.910    0.000   71.757    0.001 /home/antolikjan/virt_env/mozaikluca/lib/python3.12/site-packages/neo/core/spiketrain.py:260(__new__)
#         9    0.403    0.045   62.081    6.898 /usr/lib/python3.12/asyncio/base_events.py:1910(_run_once)
# 700000/400000    1.415    0.000   58.650    0.000 /home/antolikjan/virt_env/mozaikluca/lib/python3.12/site-packages/quantities/quantity.py:118(__new__)
#    100000    1.345    0.000   47.930    0.000 /home/antolikjan/virt_env/mozaikluca/lib/python3.12/site-packages/quantities/quantity.py:202(rescale)

# %%
import pstats
from pstats import SortKey

p = pstats.Stats('restats1')
p.sort_stats(SortKey.CUMULATIVE).print_stats(5)
p = pstats.Stats('restats2')
p.sort_stats(SortKey.CUMULATIVE).print_stats(5)
p = pstats.Stats('restats3')
p.sort_stats(SortKey.CUMULATIVE).print_stats(5)
# Out:
# Fri Jan 17 15:32:03 2025    restats1
#
#          61782496 function calls (56871445 primitive calls) in 129.542 seconds
#
#    Ordered by: cumulative time
#    List reduced from 321 to 5 due to restriction <5>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.000    0.000  144.434  144.434 {built-in method builtins.exec}
#         1    0.000    0.000  144.432  144.432 /tmp/ipykernel_217470/711785878.py:8(aaa1)
#        10    0.001    0.000  144.422   14.442 /home/antolikjan/virt_env/mozaikluca/lib/python3.12/site-packages/mozaik/storage/neo_neurotools_wrapper.py:47(get_spiketrains)
#        10    3.813    0.381  134.917   13.492 {built-in method _pickle.load}
#    134990    1.010    0.000  107.721    0.001 /home/antolikjan/virt_env/mozaikluca/lib/python3.12/site-packages/neo/core/spiketrain.py:96(_new_spiketrain)
#
#
# Fri Jan 17 15:32:04 2025    restats2
#
#          404995 function calls in 0.283 seconds
#
#    Ordered by: cumulative time
# ...

# %%
def aaa4():
    for sp in sps:
        a = SpikeTrain([1,1]*s,t_stop=10000)
        
cProfile.run('aaa4()', 'restats4')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 5
#       2     for sp in sps:
#       3         a = SpikeTrain([1,1]*s,t_stop=10000)
# ----> 5 cProfile.run('aaa4()', 'restats4')
#
# File /usr/lib/python3.12/cProfile.py:18, in run(statement, filename, sort)
#      17 def run(statement, filename=None, sort=-1):
# ---> 18     return _pyprofile._Utils(Profile).run(statement, filename, sort)
#
# File /usr/lib/python3.12/profile.py:55, in _Utils.run(self, statement, filename, sort)
#      53 prof = self.profiler()
#      54 try:
# ---> 55     prof.run(statement)
#      56 except SystemExit:
#      57     pass
#
# File /usr/lib/python3.12/cProfile.py:97, in Profile.run(self, cmd)
#      95 import __main__
#      96 dict = __main__.__dict__
# ---> 97 return self.runctx(cmd, dict, dict)
#
# ...

# %%
# Out:
# 134990

# %%
p = pstats.Stats('restats3')
p.sort_stats(SortKey.CUMULATIVE).print_stats(20)
# Out:
# Fri Jan 17 16:57:33 2025    restats3
#
#          32110004 function calls (30810004 primitive calls) in 34.934 seconds
#
#    Ordered by: cumulative time
#    List reduced from 66 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   35.045   35.045 {built-in method builtins.exec}
#         1    0.716    0.716   35.044   35.044 /home/antolikjan/projects/mozaikluca/mozaik-contrib/BenScholl/a.py:5(aaa3)
#    130000    1.061    0.000   25.042    0.000 /home/antolikjan/virt_env/mozaikluca/lib/python3.12/site-packages/neo/core/spiketrain.py:260(__new__)
#    390000    0.759    0.000   12.960    0.000 /home/antolikjan/virt_env/mozaikluca/lib/python3.12/site-packages/quantities/registry.py:62(__getitem__)
#    130000    0.686    0.000   12.613    0.000 /home/antolikjan/virt_env/mozaikluca/lib/python3.12/site-packages/neo/core/spiketrain.py:50(_check_time_in_range)
# ...

# %%
p = pstats.Stats('restats3')
p.sort_stats(SortKey.CUMULATIVE).print_stats(20)
# Out:
# Fri Jan 17 16:47:17 2025    restats3
#
#          2990004 function calls in 2.220 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    2.220    2.220 {built-in method builtins.exec}
#         1    0.000    0.000    2.220    2.220 <string>:1(<module>)
#         1    0.077    0.077    2.220    2.220 /home/antolikjan/projects/mozaikluca/mozaik-contrib/BenScholl/a.py:5(aaa3)
#    130000    0.102    0.000    2.143    0.000 /home/antolikjan/virt_env/mozaikluca/lib/python3.12/site-packages/quantities/unitquantity.py:205(__rmul__)
#    130000    0.598    0.000    1.584    0.000 /home/antolikjan/virt_env/mozaikluca/lib/python3.12/site-packages/quantities/quantity.py:356(__rmul__)
#    130000    0.214    0.000    0.703    0.000 /home/antolikjan/virt_env/mozaikluca/lib/python3.12/site-packages/quantities/quantity.py:270(__array_prepare__)
# ...

# %%
a=[1,1]*ms
a.dtype
# Out:
# dtype('float64')
